# %% [markdown]
# # PIPELINE

# %%
from sentence_transformers import SentenceTransformer, util
from utils.operate_data import load_dataset as dd_load_dataset
from utils.autocomplete import yolo_utils as yolo
import pandas as pd

from transformers import AutoTokenizer
from transformers import AutoModelForSeq2SeqLM

from sklearn.cluster import AgglomerativeClustering
from sklearn.model_selection import train_test_split
import numpy as np



from tqdm import tqdm
tqdm.pandas()

# %matplotlib inline

# %% [markdown]
# ## get data

# %%
df_meta, _ = dd_load_dataset('/local_data/meta_data/', df_name = 'meta.pickle', files_df_name=None)
df_meta.reset_index(inplace=True)

df_prepared = pd.read_pickle('/local_data/meta_data/prepared_files.pickle')
df_prepared = df_prepared[df_prepared.extension == '.pdf']
df_prepared = df_prepared[df_prepared.content.agg(len) != 0]
df_prepared = df_prepared.loc[df_prepared.groupby('doc_id')['order'].idxmax()]
df_prepared.rename(columns={'content': 'text'}, inplace=True)

df_content = df_prepared.merge(df_meta, on='doc_id')
df_content = df_content[['doc_id', 'text', 'content']]

# %%
# for research
# df_content = df_content.head(100)

# %%
# model_sentence = SentenceTransformer('bert-base-nli-mean-tokens')
# model_sentence.save('/local_data/models/text_matching/')

# %%
model_summarization = AutoModelForSeq2SeqLM.from_pretrained( '/local_data/summarization/models/csebuetnlp_mT5_m2o_russian_crossSum/')
tokenizer = AutoTokenizer.from_pretrained('/local_data/summarization/data/csebuetnlp_mT5_m2o_russian_crossSum')

# %% [markdown]
# # get summarization

# %%
def summarizer(text: str, tokenizer: AutoTokenizer, model = AutoModelForSeq2SeqLM) -> str:
    
    inputs = tokenizer(text, max_length=1024, truncation=True, return_tensors="pt").input_ids
    outputs = model.generate(inputs, max_new_tokens=200, do_sample=False)
    
    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# %%
# при необходимости получить суммаризацию. для экспериментов достаточно пользоваться фичёй content

# df_content['predict_summary'] = df_content['text'].progress_apply(lambda row: summarizer(row, tokenizer, model_summarization))

# %% [markdown]
# # get embeddings with sentence transformer

# %%
# %%time
corpus = df_content['content'].to_list()
corpus_embeddings = model_sentence.encode(corpus, convert_to_tensor=True)
# Out:
# CPU times: user 1h 3min 34s, sys: 2min 23s, total: 1h 5min 58s
# Wall time: 4min 11s

# %% [markdown]
# # Cross Encoding

# %%
from sentence_transformers.cross_encoder import CrossEncoder

# %%
num_candidates = 500
max_corpus_size = 20000

# %%
cross_encoder_model = CrossEncoder('cross-encoder/stsb-distilroberta-base')

# %%
# example
# sentence_pairs = [['О согласовании проекта внесения изменений в генеральный план', 'О вопросах согласования проекта внесения изменений в генеральный план']]
# ce_scores = cross_encoder_model.predict(sentence_pairs)
# ce_scores
# Out:
# array([    0.96888], dtype=float32)

# %%
# %%time
query = df_content.iloc[88].content
sentence_combinations = [[query, sentence] for sentence in corpus[:1000]]

similarity_scores = cross_encoder_model.predict(sentence_combinations)
# Out:
# CPU times: user 22min 53s, sys: 4min 55s, total: 27min 49s
# Wall time: 1min 59s

# %%
sim_scores_argsort = reversed(np.argsort(similarity_scores))

# %%
# Print the scores
print("Query:", query)
c = 0
for idx in sim_scores_argsort:
    print("{:.2f}\t{}".format(similarity_scores[idx], corpus[idx]))
    c += 1
    if c >= 10:
        break
# similarity_scores[0], corpus[0]
# Out:
# Query: О согласовании проекта внесения изменений в генеральный план
# 0.92	О вопросах согласования проекта генерального плана
# 0.92	О вопросах согласования проекта генерального плана
# 0.91	О вопросах согласования проектов схем территориального планирования
# 0.91	О вопросах согласования проектов схем территориального планирования
# 0.91	О согласовании проекта федерального закона «О внесении изменений в Федеральный закон «Об использовании атомной энергии» в части регулирования безопасности деятельности по эксплуатации радиационны х источников и оценки соответствия оборудования, изделий и технологий (процессов) для объектов использования атомной энергии»
# 0.91	О согласовании проекта Правительства Российской Федерации "О внесении изменений в Положение об управлении находящимися в федеральной собственности акциями акционерных обществ и использовании специального права на участие Российской Федерации в управлении акционерными обществами ("золотой акции")
#
# 0.91	О законопроектах, направленных на совершенствование земельного законодательства
# 0.90	О мониторинге  соблюдения  предельного  уровня  соотношения  среднемесячной заработной  платы  руководителей,  заместителей  руководителей и  главных  бухгалтеров  федеральных  учреждений  и  федеральных государственных  унитарных  предприятий,  подведомственных  федеральным органам  исполнительной  власти  и  государственным  корпорациям
# 0.90	О проекте  постановления  Правительства  Российской  Федерации  «О  внесении изменений в некоторые акты Правительства Российской Федерации по вопросамреализации конфискованного или изъятого  из незаконного оборота по решению суда  автомобильного  транспорта,  используемого  для  незаконной  перевозки этилового спирта, алкогольной и спиртосодержащей продукции»
# 0.90	О  ходе  рассмотрения  вопроса целесообразности  дальнейшей  проработки  проекта  федерального закона "О  внесении  изменений  в  Закон  Российской  Федерации  "О  государственной границе  Российской  Федерации"  и  отдельные  законодательные  акты Российской  Федерации"  с  учетом  принятых  решений  по  внедрению электронного  документооборота  при  осуществлении  государственного контроля  в  морских  пунктах  пропуска  через  государственную  границу
# Российской  Федерации  (поручение  Правительства  Российской  Федерации от  23  августа  2019  г.  №  СА-П4-7236)

# %%
len(corpus[1:100]), len(similarity_scores)
# Out:
# (99, 99)

# %% [markdown]
# # Community detection

# %%
# %%time
# clusters = util.community_detection(corpus_embeddings, min_community_size=25, threshold=0.5)

# %%
clusters[0][-1]
# Out:
# 8057

# %%
#Print for all clusters the top 3 and bottom 3 elements
for i, cluster in enumerate(clusters):
    print("\nCluster {}, #{} Elements ".format(i+1, len(cluster)))
    # for sentence_id in cluster[0:3]:
    #     print("\t", corpus[sentence_id])
    # print("\t", "...")
    # for sentence_id in cluster[-3:]:
    #     print("\t", corpus[sentence_id])
    # break
# Out:
# Cluster 1, #8057 Elements

# %% [markdown]
# # DBSCAN

# %%
from sklearn.cluster import DBSCAN

# %%
db = DBSCAN(eps=0.05, min_samples=2, leaf_size=2).fit(corpus_embeddings)

# %%
db.labels_
# Out:
# array([ -1,  -1,   0, ...,  -1, 367,  -1])

# %%
df_content['cluster'] = db.fit_predict(corpus_embeddings)

# %%
df_content.cluster.value_counts()
# Out:
# cluster
# -1      6631
#  8        26
#  7        24
#  33       22
#  56       21
#         ...
#  205       2
#  204       2
#  203       2
#  202       2
#  445       2
# Name: count, Length: 447, dtype: int64

# %% [markdown]
# # Aglomerative Clustering to set the number of clusters

# %%
# %%time
# изменить фичу content на predict_summary при необходимости

# Normalize the embeddings to unit length
np_corpus_embeddings = corpus_embeddings /  np.linalg.norm(corpus_embeddings, axis=1, keepdims=True)
# Out:
# CPU times: user 6.85 ms, sys: 0 ns, total: 6.85 ms
# Wall time: 5.75 ms

# %%
# 0.05

# %%
# %%time
# Perform kmean clustering
clustering_model = AgglomerativeClustering(n_clusters=None, distance_threshold=0.04,  
                                           affinity = 'cosine', linkage ='average')
clustering_model.fit(np_corpus_embeddings)
cluster_assignment = clustering_model.labels_
# Out:
# CPU times: user 6.25 s, sys: 79.9 ms, total: 6.33 s
# Wall time: 6.33 s

# %%
clustered_sentences = {}
for sentence_id, cluster_id in enumerate(cluster_assignment):
    if cluster_id not in clustered_sentences:
        clustered_sentences[cluster_id] = []

    clustered_sentences[cluster_id].append(corpus[sentence_id])

# %%
df_content['cluster'] = clustering_model.fit_predict(np_corpus_embeddings)

# %%
print(f'количество документов: {df_content.shape[0]},\nколичество кластеров: {len(clustered_sentences.items())}')
# Out:
# количество документов: 8058,
# количество кластеров: 1084

# %%
df_content.iloc[476]['cluster']
# Out:
# 5

# %%
# cluster_assignment[7984]

# %%
# df_content[df_content.cluster == 161]

# %% [markdown]
# ## Set only big clusters

# %%
corpus_embeddings.shape, cluster_assignment.shape
# Out:
# (torch.Size([8058, 768]), (8058,))

# %%
corpus_emb= corpus_embeddings[:10000, :]
cluster_assign = cluster_assignment[:10000]

# %%
df_clusters = pd.DataFrame(corpus_emb)
features = df_clusters
df_clusters['cluster'] = cluster_assign
df_clusters.columns = df_clusters.columns.map(str)

# %%
df_clusters.cluster.nunique()
# Out:
# 1084

# %%
# создание списка кластеров имеющих менее "x" экземпляров

x = 10
num_clusters = df_clusters.cluster.value_counts().to_dict()

single_clusters = []
for key, val in num_clusters.items():
    if val <= x:
        single_clusters.append(key)
len(single_clusters)
# Out:
# 992

# %%
# кластеры имеющие количество экземпляров менее 20 объединяются в один кластер
last_cluster = len(clustered_sentences.items()) + 1 # нэйминг последнего объеденённого кластера
df_clusters['cluster'] = df_clusters['cluster'].apply(lambda row: last_cluster  if row in single_clusters else row)

# %%
df_clusters.cluster.nunique()
# Out:
# 93

# %%
target = df_clusters['cluster']

# %%
# df_clusters = pd.DataFrame(corpus_emb)
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.3, random_state=42)

# %%
# from sklearn.cluster import DBSCAN
# from sklearn.cluster import KMeans
# from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Random Forest Classifier for predict clusters

# %%
from sklearn.model_selection import GridSearchCV#, HalvingGridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score

# %%
# param_grid = { 
#     'n_estimators': [700, 1000],
#     'criterion': ['gini', 'entropy', 'log_loss'],
#     'min_samples_split':[5,10,20]
# }

# %%
# CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv=3)
# CV_rfc.fit(X_train, y_train)
# print (CV_rfc.best_params_)

# %%
# params = CV_rfc.best_params_
rfc = RandomForestClassifier(random_state=42, verbose=1, n_jobs=2)#, **params)
rfc.fit(X_train, y_train)
predicts = rfc.predict(X_test)
# Out:
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=2)]: Done 100 out of 100 | elapsed:    4.4s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done 100 out of 100 | elapsed:    0.0s finished

# %%
params
# Out:
# {'criterion': 'gini', 'min_samples_split': 5, 'n_estimators': 1000}

# %%
precision_score(y_test, predicts, average='weighted'), recall_score(y_test, predicts, average='weighted')
# Out:
# /opt/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# (0.8754299235939375, 0.8606286186931348)

# %%
predicts
# Out:
# array([   5,    5, 1085, ..., 1085, 1085, 1085])

# %% [markdown]
# # CatBoost for predict clusters

# %%
from catboost import CatBoostClassifier
from catboost import CatBoostRegressor


from sklearn.metrics import precision_score, recall_score
cat = CatBoostClassifier(random_state=42)

# %%
# %%time
cat.fit(X_train,y_train, verbose=False, plot=False)
# Out:
# CPU times: user 17h 45min 54s, sys: 49.1 s, total: 17h 46min 43s
# Wall time: 46min 41s

# %%
# from catboost import Pool, cv
# params = {"iterations": 100,
#           "depth": 2,
#           "loss_function": "RMSE",
#           "verbose": False}
# cv_dataset = Pool(data=X_train,
#                   label=y_train)
# scores = cv(cv_dataset,
#             params,
#             fold_count=2, 
#             plot="True")

# %%
cat.predict(X_test)
# Out:
# array([[   5],
#        [   5],
#        [ 480],
#        ...,
#        [1085],
#        [   5],
#        [1085]])

# %%
predicts = cat.predict(X_test)

# %%
precision_score(y_test, predicts, average='weighted'), recall_score(y_test, predicts, average='weighted')
# Out:
# (0.9890440710432155, 0.9884201819685691)

# %%
cat.save_model('/local_data/models/text_matching/catboost_clusters.cbm')

# %%
y_test.head(30)
# Out:
# 3826       5
# 4823       5
# 2034     480
# 5928      45
# 3341       5
# 2107    1085
# 5086      52
# 222       77
# 6706     161
# 3703     268
# 2619     103
# 5602    1085
# 4857      57
# 8044       5
# 5995     103
# 2929     263
# 6152       6
# 6127      77
# 4262     127
# 4652    1085
# 7148    1085
# 2534       5
# 1075    1085
# 5351      38
# 472       77
# 4706     137
# 3482       5
# 6044       5
# 7374    1085
# 5817     103
# Name: cluster, dtype: int64

# %%
predicts[103]
# Out:
# array([5])

# %%
y_test.value_counts()
# Out:
# cluster
# 1085    667
# 5       602
# 161     120
# 77       90
# 6        71
#        ...
# 479       2
# 432       2
# 404       2
# 7         1
# 258       1
# Name: count, Length: 92, dtype: int64

# %% [markdown]
# ## Kmeans

# %%
mdl = KMeans(n_clusters=90)
mdl.fit(X_train)
predicts = mdl.predict(X_test)
# Out:
# /opt/venv/lib/python3.10/site-packages/sklearn/utils/validation.py:1858: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   warnings.warn(
# /opt/venv/lib/python3.10/site-packages/sklearn/utils/validation.py:1858: FutureWarning: Feature names only support names that are all strings. Got feature names with dtypes: ['int', 'str']. An error will be raised in 1.2.
#   warnings.warn(

# %%
precision_score(y_test, predicts, average='weighted'), recall_score(y_test, predicts, average='weighted')
# Out:
# /opt/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/venv/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# (0.0, 0.0)

# %% [markdown]
# # cluster recognition

# %%
sample = 88  # 52
query = [df_content.iloc[sample]['content']]
# corpus = df_content['content'].to_list()
df_cluster = df_content[df_content.cluster == df_content.iloc[sample].cluster].reset_index()
# corpus_cluster = df_cluster['content'].to_list()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_29/2576502637.py in ?()
#       1 sample = 88  # 52
#       2 query = [df_content.iloc[sample]['content']]
#       3 # corpus = df_content['content'].to_list()
# ----> 4 df_cluster = df_content[df_content.cluster == df_content.iloc[sample].cluster].reset_index()
#       5 # corpus_cluster = df_cluster['content'].to_list()
#
# /opt/venv/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'cluster'

# %%
df_cluster
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[136], line 1
# ----> 1 df_cluster
#
# NameError: name 'df_cluster' is not defined

# %%
# query

# %%
# corpus_cluster

# %%
# %%time
embeddings_query = model_sentence.encode(query, convert_to_tensor=True)
embeddings_corpus = model_sentence.encode(corpus_cluster, convert_to_tensor=True)
top = util.semantic_search(embeddings_query, embeddings_corpus, score_function=util.cos_sim, top_k= 5)[0]
matching = {}
for doc in top:
    doc_id = df_cluster.iloc[doc['corpus_id']]['doc_id']
    matching[doc_id] = doc['score']
# Out:
# CPU times: user 10.3 s, sys: 25.4 ms, total: 10.4 s
# Wall time: 658 ms

# %%
corpus_embeddings
# Out:
# tensor([[-0.4683,  0.3372,  0.9311,  ...,  0.0400,  0.0779,  0.3649],
#         [-0.6288,  0.2307,  0.9192,  ..., -0.1604,  0.4529,  0.5103],
#         [-0.5409,  0.2283,  1.0933,  ..., -0.0259,  0.1508,  0.5428],
#         ...,
#         [-0.6407,  0.1795,  0.9143,  ...,  0.0736,  0.3708,  0.3535],
#         [-0.5498,  0.3906,  1.3660,  ..., -0.0556,  0.1707, -0.0072],
#         [-0.6638,  0.4813,  0.9552,  ...,  0.0291,  0.1848,  0.5233]])

# %%
# %%time
embeddings_query = model_sentence.encode(query, convert_to_tensor=True)
top = util.semantic_search(embeddings_query, corpus_embeddings, score_function=util.cos_sim, top_k= 5)[0]
matching = {}
for doc in top:
    doc_id = df_content.iloc[doc['corpus_id']]['doc_id']
    matching[doc_id] = doc['score']
# Out:
# CPU times: user 4.35 s, sys: 0 ns, total: 4.35 s
# Wall time: 439 ms

# %%
matching
# Out:
# {'c95c2c21-8a61-4023-ad8f-25faaf3cf687': 1.000000238418579,
#  '1869c7c4-c00d-41f9-b5ee-211dc204eb29': 1.0000001192092896,
#  '11439a8e-a2f9-465a-829c-be77a363d065': 1.0000001192092896,
#  '02f3049d-6989-44df-85c1-be9d91344b09': 1.0000001192092896,
#  '2d8435fe-9c60-449d-af4c-b8549100b93f': 1.0000001192092896}

# %%
yolo.show_pdf('c95c2c21-8a61-4023-ad8f-25faaf3cf687')
# Out:
# \includegraphics[width=1.0\textwidth]{data:application/pdf;base64,...}

# %%
yolo.show_pdf('11439a8e-a2f9-465a-829c-be77a363d065')
# Out:
# \includegraphics[width=1.0\textwidth]{data:application/pdf;base64,...}

# %%
df_content.cluster.value_counts()
# Out:
# cluster
# 5       1951
# 161      401
# 77       336
# 6        248
# 127      187
#         ...
# 1036       1
# 998        1
# 713        1
# 335        1
# 854        1
# Name: count, Length: 1084, dtype: int64

# %%
num_clusters = df_content.cluster.value_counts().to_dict()

# %%
cl = []
for key, val in num_clusters.items():
    if val == 1:
        cl.append(key)
len(cl)
# Out:
# 551

# %%
df_content[df_content.cluster == 1004]
# Out:
#                                     doc_id  \
# 88    02f3049d-6989-44df-85c1-be9d91344b09
# 97    0327b03d-ec0d-4e5a-abfe-77eded58c00b
# 544   11439a8e-a2f9-465a-829c-be77a363d065
# 782   1869c7c4-c00d-41f9-b5ee-211dc204eb29
# 925   1db847e3-31f3-4ff5-8177-ed6500e4760b
# 1410  2d8435fe-9c60-449d-af4c-b8549100b93f
# 1702  36cdf743-5929-4961-a7b3-f6e7cff005e0
# 1870  3c9f0d3b-8611-4174-a9aa-80cda54a33df
# 2250  4834c6b2-cdb2-409b-ad7c-695b738310b3
# 2396  4cb92317-c185-48a9-8126-909c1c774497
# 2441  4e639381-f56e-40ed-bc34-962869aafb67
# 2765  5990d439-cf0c-4689-b606-50611a181747
# 3011  614be47d-dcb4-4034-83f0-66a924967b1a
# 3584  72ddedfa-801d-4048-94cc-8a5870bb8799
# 3682  75f3693b-ee2c-414f-a1d3-8167f092433c
# 4188  856f30dd-158a-439f-be25-fdec85db9dce
# 4280  88aff66c-f2ef-4b47-b071-9632dceaf0df
# 4473  8f3dbe93-7c28-43a3-8236-b93d548da79f
# 4765  989bf6c3-a5a4-44aa-8abe-91d7d3624c6d
# 4847  9b4d6c64-eede-461c-8b85-327415d02db8
# 5515  afd841b2-7c63-4a44-ba01-bb908b040593
# 6318  c95c2c21-8a61-4023-ad8f-25faaf3cf687
# 6564  d029425b-7cc5-4b34-b580-78b8cd38c4c4
# 6646  d2cef920-4310-4f39-bc9c-16b1e411a883
# 6831  d9237b93-f194-45fc-a8a7-33011c51c5ae
# 6885  dab83fca-79d9-4be3-9787-843a1fde7c88
# 6923  dbb524c8-0624-407c-9a6e-57492b94e596
# 6979  dd7e1c41-2e28-430f-ad5a-135cc998575f
# 7282  e7aea2ea-ce5c-49c3-9e3f-aa2a6f11538a
# 7397  eb08c73f-6bb4-4717-98f3-a00e8f38edf0
# 7652  f2ef995c-3676-4b81-b756-3235c226cf3d
# 7799  f70f608f-9522-4cd5-ab27-612b993b16ca
# 7972  fcff336d-8f17-4fd1-a0eb-986b0f4b1d5f
#
#                                                    text  \
# 88    департамент планирования территориального разв...
# 97    департамент планирования россии территориально...
# 544   министерство обороны российской федерации мино...
# 782   министерство обороны российской федерации мино...
# 925   федеральная служба войск национальной гвардии ...
# 1410  департамент планирования территориального разв...
# 1702  федеральная служба войск национальной гвард ро...
# 1870  департамент планирования территориального разв...
# 2250  министерство департамент планирования россии т...
# 2396  департамент планирования территориального разв...
# 2441  экз федеральная служба охраны российской федер...
# 2765  департамент планирования россии территориально...
# 3011  федеральная служба войск национальной гвардии ...
# 3584  администрация сельского поселения старое усман...
# 3682  администрация сельского поселения новое якушки...
# 4188  администрация сельского поселения ермаково мун...
# 4280  федеральная служба войск национальной гвардии ...
# 4473  федеральная служба войск национальной гвардии ...
# 4765  рсісс^скойвфедарации департамент планирования ...
# 4847  федеральная служба войск национальной гвардии ...
# 5515  федеральная служба войск национальной гвардии ...
# 6318  министру экономического развития российской фе...
# 6564  департамент планирования российском федерации ...
# 6646  администрация сельского поселения васильевка м...
# 6831  закрытого административно территориального обр...
# 6885  федеральная служба войск национальной гвардии ...
# 6923  департамент планирования территориального разв...
# 6979  администрация сельского поселения новое усмано...
# 7282  департамент планирования российской федерации ...
# 7397  федеральная служба войск национальной гвардии ...
# 7652  департамент планирования российской федерации ...
# 7799  администрация сельского поселения старое вечка...
# 7972  федеральная служба департамент планирования те...
#
#                                                 content  cluster
# 88    О согласовании проекта внесения изменений в ге...     1004
# 97    О согласовании проекта внесения изменений в ге...     1004
# 544   О согласовании проекта внесения изменений в ге...     1004
# 782   О согласовании проекта внесения изменений в ге...     1004
# 925   О вопросах согласования проекта внесения измен...     1004
# 1410  О согласовании проекта внесения изменений в ге...     1004
# 1702  О вопросах согласования проекта внесения измен...     1004
# 1870  О согласовании проекта внесения изменений в ге...     1004
# 2250  О согласовании проекта внесения изменений в ге...     1004
# 2396  О согласовании проекта внесения изменений в ге...     1004
# 2441  О согласовании проектов внесения изменений в г...     1004
# 2765  О согласовании проекта внесения изменений в ге...     1004
# 3011  О вопросах согласования проекта внесения измен...     1004
# 3584  О согласовании проекта внесения изменений в Ге...     1004
# 3682  О согласовании проекта внесения изменений в Ге...     1004
# 4188  О согласовании проекта внесения изменений в Ге...     1004
# 4280  О вопросах согласования проекта внесения измен...     1004
# 4473  О вопросах согласования проекта внесения измен...     1004
# 4765  О согласовании проекта внесения изменений в ге...     1004
# 4847  О вопросах согласования проекта внесения измен...     1004
# 5515  О вопросах согласования проекта внесения измен...     1004
# 6318  О согласовании проекта внесения изменений в Ге...     1004
# 6564  О согласовании проекта внесения изменений в ге...     1004
# 6646  О согласовании проекта внеения изменений в Ген...     1004
# 6831  О согласовании проекта внесения изменений в ге...     1004
# 6885  О вопросах согласования проекта внесения измен...     1004
# 6923  О согласовании проекта внесения изменений в ге...     1004
# 6979  О согласовании проекта внесения изменений в Ге...     1004
# 7282  О согласовании проекта внесения изменений в ге...     1004
# 7397  О вопросах согласования проекта внесения измен...     1004
# 7652  О согласовании проекта внесения изменений в ге...     1004
# 7799  О согласовании проекта внесения изменений в Ге...     1004
# 7972  О вопросах согласования проекта внесения измен...     1004

# %%
pd.read_pickle('/local_data/summarization/data/df_summary.pickle')
# Out:
#                                     doc_id  \
# 2     f5805e2c-0ed3-40e4-a16e-5f2370d0412d
# 5     6bab4407-7afd-45bb-9c19-95aeb4055930
# 6     b98b4f3d-08df-4bc2-85a4-90f1af724ad6
# 8     ef76b51a-3f85-4eca-9cb5-20c45f9eb929
# 9     24f62e09-44a5-4284-8ef5-8db6e0d55f0e
# ...                                    ...
# 3424  ed1bd9ae-a134-4e61-b9a3-277aa9e4aa8a
# 3425  60d7f317-622f-489f-9427-e0de2972192a
# 3427  ddb82548-96c7-4a1d-9ad3-c9c351e9938d
# 3428  f3a088e7-ccbd-4c6a-b5cc-5ca8cde451ed
# 3433  7b8c6f1f-8901-4d11-99b2-19d14b7299f3
#
#                                                    text    kind  \
# 2     Информируем о том, что среди предприятий-участ...  Письмо
# 5     В соответствии с письмом Минэкономразвития Рос...  Письмо
# 6     Территориальное управление Росимущества в горо...  Письмо
# 8     В дополнение к письму Аппарата Правительства Р...  Письмо
# 9     В соответствии с поручением Правительства Росс...  Письмо
# ...                                                 ...     ...
# 3424  В связи с Вашим запросом направляем статистиче...  Письмо
# 3425  Федеральное государственное бюджетное образова...  Письмо
# 3427  Федеральное агентство по туризму — государстве...  Письмо
# 3428  В рамках актуализации сведений в автоматизиров...  Письмо
# 3433  Федеральное агентство связи в рамках исполнени...  Письмо
#
#                                                 summary  len_content  len_text
# 2     О разъяснении пунктов Соглашения о сотрудничес...          249       573
# 5     Об исполнении поручения Минэкономразвития Росс...           75       542
# 6     О предоставлении выписок из реестра федерально...          102       495
# 8     О позиции Верховного Суда Российской Федерации...          133       325
# 9     О предложениях по учету места происхождения эк...           64      2344
# ...                                                 ...          ...       ...
# 3424  О статистике экспорта из Латвии в Россию, Бело...           62       221
# 3425  О направлении формы "Сведения о доходах, получ...           93       417
# 3427  О направлении уточненной информации по форме 1...           62       691
# 3428  Об актуализации сведений в автоматизированной ...           98       803
# 3433  О сведениях, подлежащих представлению с исполь...           64       326
#
# [1852 rows x 6 columns]
